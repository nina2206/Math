# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-2*np.pi, 3*np.pi, 201)
plt.plot(x, np.cos(x))
plt.plot(x, 2*np.cos(x-1)+3)
plt.grid(True)
plt.show()
